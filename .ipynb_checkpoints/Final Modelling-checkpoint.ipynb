# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
url = r'C:\Users\nitinkohli\MIAS\label_removal_1'

info = pd.read_csv(r'C:\Users\nitinkohli\MIAS\Info.txt', sep=" ")

# %%
info.drop_duplicates(subset = "REFNUM", keep = 'first', inplace = True)
info.reset_index(inplace = True)
info.shape
# Out:
# (322, 9)

# %%
img_name = []
for i in range(info.shape[0]):
        img_name.append(info.REFNUM[i]+ '.pgm')
        
img_add = []
for i in range(info.shape[0]):
    img_add.append(url + '\\' +info.REFNUM[i]+ '.pgm')

label = []
for i in range(len(info)):
    if info.SEVERITY[i] == 'B':
        label.append(1)
    else:
        label.append(0)

# %%
def save_dictionary(path,data):
    print('saving catalog...')
    #open('u.item', encoding="utf-8")
    import json
    with open(path,'w') as outfile:
      json.dump(str(data), fp=outfile)
      # save to file:
    print('catalog saved')

# %%
import random
# view images
def view_25_random_image():
    fig = plt.figure(figsize = (25, 15))
    for i in range(0, 25):
        rand = random.randint(0,len(img_add))
    
        img = cv2.imread(img_add[rand], 1)
        img = cv2.resize(img, (256,256))
        ax = plt.subplot(5, 5, i+1)
        plt.tight_layout()
        plt.axis('off')
        plt.title(img_name[rand])
        plt.imshow(img)
random_images = view_25_random_image()

# %%
start = 0
end = 360
step = 1

# %%
def read_image():
    print("Reading images")
    import cv2
    info = {}
    for i in range(322):
        if i<9:
            image_name='mdb00'+str(i+1)
        elif i<99:
            image_name='mdb0'+str(i+1)
        else:
            image_name = 'mdb' + str(i+1)
#         print(image_name)
        image_address = url + '\\' + image_name + '.pgm'
#         print(image_address)
        img = cv2.imread(image_address, 0)
#         print(i)
        try:
            img = cv2.resize(img, (64, 64))   #resize image
            rows, cols = img.shape
            info[image_name]={}
            for angle in range(start, end, step):
                M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)    #Rotate 0 degree
                img_rotated = cv2.warpAffine(img, M, (cols, rows))
                info[image_name][angle]=img_rotated
        except:
            print("except")
    return (info)

# %%
def labelling():
    df = pd.read_csv(r'C:\Users\nitinkohli\MIAS\Info.txt', sep=" ")
    df.drop_duplicates(subset = "REFNUM", keep = 'first', inplace = True)
    df.reset_index(inplace = True)
    print("labelling")
    info={}
    for i in range(len(df)):
        if (df.CLASS[i] == "NORM"):
            info[df.REFNUM[i]] = {}
            for angle in range(start, end, step):
                info[df.REFNUM[i]][angle] = 0
        else:
            info[df.REFNUM[i]] = {}
            if (df.SEVERITY[i] == 'B'):
                for angle in range(start, end, step):
                    info[df.REFNUM[i]][angle] = 1
            elif (df.SEVERITY[i] == 'M'):
                for angle in range(start, end, step):
                    info[df.REFNUM[i]][angle] = 2
    return (info)

# %%
from sklearn.model_selection import train_test_split

# %%
label_info = labelling()
image_info = read_image()
ids = label_info.keys()
# Out:
# labelling
# Reading images

# %%
len(ids)
# Out:
# 322

# %%
X=[]
Y=[]
for id in ids:
    for angle in range(start, end, step):
        X.append(image_info[id][angle])
        Y.append(label_info[id][angle])
X=np.array(X)
Y=np.array(Y)

# %%
print(len(X))
print(len(Y))
# Out:
# 115920
# 115920

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
(a,b,c)=x_train.shape
x_train = np.reshape(x_train, (a, b, c, 1))  #1 for gray scale
(a, b, c)=x_test.shape
x_test = np.reshape(x_test, (a, b, c, 1))   #1 for gray scale
print(x_train.shape)
print(x_test.shape)
# Out:
# (92736, 64, 64)
# (23184, 64, 64)
# (92736,)
# (23184,)
# (92736, 64, 64, 1)
# (23184, 64, 64, 1)

# %%
import tensorflow as tf
from tensorflow import keras
from keras.utils import to_categorical
Y_test = to_categorical(y_test)
Y_train = to_categorical(y_train)

# %%
#libraries for deep learning (CNN)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Conv2D, MaxPool2D, Flatten
from keras import optimizers
from keras import losses
from sklearn import metrics

# %%
rows, cols, color = x_train[0].shape
print(rows)
print(cols)
model = Sequential()
model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='same', input_shape=(rows,cols,1), activation="relu"))

model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))

model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation="relu"))

model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))

model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Dropout(0.25))

model.add(Dense(64, activation="relu"))

model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(3, activation='softmax'))

model.summary()
# Out:
# 64
# 64
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 64, 64, 64)        640
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 64, 64, 64)        36928
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# dense_19 (Dense)             (None, 16, 16, 64)        8256
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 16384)             0
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 49155
# =================================================================
# Total params: 316,419
# Trainable params: 316,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', patience=5,restore_best_weights=True, verbose=1)

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, Y_train, validation_split=0.2, epochs = 100, batch_size=128, callbacks=[es])
loss_value , accuracy = model.evaluate(x_test, Y_test)

print('Test_loss_value = ' + str(loss_value))
print('test_accuracy = ' + str(accuracy))

save_dictionary('history1.dat', history.history)
# Out:
# Train on 74188 samples, validate on 18548 samples
# Epoch 1/100
# 74188/74188 [==============================] - 131s 2ms/step - loss: 0.9699 - accuracy: 0.6412 - val_loss: 0.8950 - val_accuracy: 0.6403
# Epoch 2/100
# 74188/74188 [==============================] - 111s 1ms/step - loss: 0.8886 - accuracy: 0.6457 - val_loss: 0.8915 - val_accuracy: 0.6412
# Epoch 3/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.8840 - accuracy: 0.6456 - val_loss: 0.8841 - val_accuracy: 0.6414
# Epoch 4/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.8760 - accuracy: 0.6455 - val_loss: 0.8844 - val_accuracy: 0.6398
# Epoch 5/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.8576 - accuracy: 0.6480 - val_loss: 0.8475 - val_accuracy: 0.6445
# Epoch 6/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.8225 - accuracy: 0.6568 - val_loss: 0.7874 - val_accuracy: 0.6728
# Epoch 7/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.7708 - accuracy: 0.6766 - val_loss: 0.7351 - val_accuracy: 0.6934
# Epoch 8/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.7094 - accuracy: 0.6997 - val_loss: 0.6595 - val_accuracy: 0.7250
# Epoch 9/100
# 74188/74188 [==============================] - 109s 1ms/step - loss: 0.6685 - accuracy: 0.7191 - val_loss: 0.5773 - val_accuracy: 0.7586
# Epoch 10/100
# 74188/74188 [==============================] - 109s 1ms/step - loss: 0.5866 - accuracy: 0.7538 - val_loss: 0.4964 - val_accuracy: 0.7955
# Epoch 11/100
# 74188/74188 [==============================] - 109s 1ms/step - loss: 0.5222 - accuracy: 0.7828 - val_loss: 0.4610 - val_accuracy: 0.8040
# Epoch 12/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.4671 - accuracy: 0.8065 - val_loss: 0.3922 - val_accuracy: 0.8378
# Epoch 13/100
# 74188/74188 [==============================] - 113s 2ms/step - loss: 0.4186 - accuracy: 0.8292 - val_loss: 0.3300 - val_accuracy: 0.8640
# Epoch 14/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.3794 - accuracy: 0.8479 - val_loss: 0.3006 - val_accuracy: 0.8837
# Epoch 15/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.3416 - accuracy: 0.8652 - val_loss: 0.2488 - val_accuracy: 0.9061
# Epoch 16/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.3152 - accuracy: 0.8757 - val_loss: 0.2355 - val_accuracy: 0.9177
# Epoch 17/100
# 74188/74188 [==============================] - 109s 1ms/step - loss: 0.2960 - accuracy: 0.8848 - val_loss: 0.2099 - val_accuracy: 0.9266
# Epoch 18/100
# 74188/74188 [==============================] - 109s 1ms/step - loss: 0.2700 - accuracy: 0.8965 - val_loss: 0.1912 - val_accuracy: 0.9311
# Epoch 19/100
# 74188/74188 [==============================] - 109s 1ms/step - loss: 0.2540 - accuracy: 0.9044 - val_loss: 0.1600 - val_accuracy: 0.9433
# Epoch 20/100
# 74188/74188 [==============================] - 109s 1ms/step - loss: 0.2345 - accuracy: 0.9126 - val_loss: 0.1484 - val_accuracy: 0.9519
# Epoch 21/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.2266 - accuracy: 0.9157 - val_loss: 0.1411 - val_accuracy: 0.9534
# Epoch 22/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.2092 - accuracy: 0.9230 - val_loss: 0.1295 - val_accuracy: 0.9561
# Epoch 23/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.1992 - accuracy: 0.9268 - val_loss: 0.1197 - val_accuracy: 0.9581
# Epoch 24/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.2014 - accuracy: 0.9276 - val_loss: 0.1232 - val_accuracy: 0.9607
# Epoch 25/100
# 74188/74188 [==============================] - 115s 2ms/step - loss: 0.1846 - accuracy: 0.9349 - val_loss: 0.0994 - val_accuracy: 0.9691
# Epoch 26/100
# 74188/74188 [==============================] - 117s 2ms/step - loss: 0.1809 - accuracy: 0.9356 - val_loss: 0.0953 - val_accuracy: 0.9703
# Epoch 27/100
# 74188/74188 [==============================] - 115s 2ms/step - loss: 0.1701 - accuracy: 0.9393 - val_loss: 0.0977 - val_accuracy: 0.9653
# Epoch 28/100
# 74188/74188 [==============================] - 117s 2ms/step - loss: 0.1652 - accuracy: 0.9422 - val_loss: 0.0860 - val_accuracy: 0.9714
# Epoch 29/100
# 74188/74188 [==============================] - 115s 2ms/step - loss: 0.1616 - accuracy: 0.9426 - val_loss: 0.0901 - val_accuracy: 0.9703
# Epoch 30/100
# 74188/74188 [==============================] - 112s 2ms/step - loss: 0.1582 - accuracy: 0.9446 - val_loss: 0.0914 - val_accuracy: 0.9704
# Epoch 31/100
# 74188/74188 [==============================] - 113s 2ms/step - loss: 0.1551 - accuracy: 0.9457 - val_loss: 0.0944 - val_accuracy: 0.9680
# Epoch 32/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.1571 - accuracy: 0.9451 - val_loss: 0.0798 - val_accuracy: 0.9766
# Epoch 33/100
# 74188/74188 [==============================] - 112s 2ms/step - loss: 0.1445 - accuracy: 0.9491 - val_loss: 0.0691 - val_accuracy: 0.9789
# Epoch 34/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.1389 - accuracy: 0.9523 - val_loss: 0.0740 - val_accuracy: 0.9754
# Epoch 35/100
# 74188/74188 [==============================] - 113s 2ms/step - loss: 0.1456 - accuracy: 0.9496 - val_loss: 0.0785 - val_accuracy: 0.9750
# Epoch 36/100
# 74188/74188 [==============================] - 118s 2ms/step - loss: 0.1357 - accuracy: 0.9524 - val_loss: 0.0726 - val_accuracy: 0.9767
# Epoch 37/100
# 74188/74188 [==============================] - 117s 2ms/step - loss: 0.1366 - accuracy: 0.9531 - val_loss: 0.0622 - val_accuracy: 0.9815
# Epoch 38/100
# 74188/74188 [==============================] - 113s 2ms/step - loss: 0.1324 - accuracy: 0.9547 - val_loss: 0.0649 - val_accuracy: 0.9801
# Epoch 39/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.1280 - accuracy: 0.9560 - val_loss: 0.0587 - val_accuracy: 0.9824
# Epoch 40/100
# 74188/74188 [==============================] - 109s 1ms/step - loss: 0.1251 - accuracy: 0.9576 - val_loss: 0.0595 - val_accuracy: 0.9820
# Epoch 41/100
# 74188/74188 [==============================] - 114s 2ms/step - loss: 0.1296 - accuracy: 0.9568 - val_loss: 0.0611 - val_accuracy: 0.9810
# Epoch 42/100
# 74188/74188 [==============================] - 114s 2ms/step - loss: 0.1214 - accuracy: 0.9592 - val_loss: 0.0603 - val_accuracy: 0.9823
# Epoch 43/100
# 74188/74188 [==============================] - 111s 1ms/step - loss: 0.1107 - accuracy: 0.9628 - val_loss: 0.0464 - val_accuracy: 0.9874
# Epoch 44/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.1141 - accuracy: 0.9625 - val_loss: 0.0495 - val_accuracy: 0.9849
# Epoch 45/100
# 74188/74188 [==============================] - 113s 2ms/step - loss: 0.1192 - accuracy: 0.9597 - val_loss: 0.0499 - val_accuracy: 0.9851
# Epoch 46/100
# 74188/74188 [==============================] - 114s 2ms/step - loss: 0.1211 - accuracy: 0.9601 - val_loss: 0.0529 - val_accuracy: 0.9856
# Epoch 47/100
# 74188/74188 [==============================] - 114s 2ms/step - loss: 0.1189 - accuracy: 0.9605 - val_loss: 0.0517 - val_accuracy: 0.9836
# Epoch 48/100
# 74188/74188 [==============================] - 118s 2ms/step - loss: 0.1088 - accuracy: 0.9637 - val_loss: 0.0436 - val_accuracy: 0.9879
# Epoch 49/100
# 74188/74188 [==============================] - 119s 2ms/step - loss: 0.1087 - accuracy: 0.9638 - val_loss: 0.0493 - val_accuracy: 0.9853
# Epoch 50/100
# 74188/74188 [==============================] - 118s 2ms/step - loss: 0.1076 - accuracy: 0.9640 - val_loss: 0.0504 - val_accuracy: 0.9856
# Epoch 51/100
# 74188/74188 [==============================] - 121s 2ms/step - loss: 0.1076 - accuracy: 0.9644 - val_loss: 0.0507 - val_accuracy: 0.9849
# Epoch 52/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.1079 - accuracy: 0.9646 - val_loss: 0.0474 - val_accuracy: 0.9857
# Epoch 53/100
# 74188/74188 [==============================] - 110s 1ms/step - loss: 0.1005 - accuracy: 0.9665 - val_loss: 0.0480 - val_accuracy: 0.9846
# Restoring model weights from the end of the best epoch.
# Epoch 00053: early stopping
# 23184/23184 [==============================] - 38s 2ms/step
# Test_loss_value = 0.04282851615249648
# test_accuracy = 0.9884402751922607
# saving catalog...
# catalog saved

# %%
import matplotlib.pyplot as plt
def Train_Val_Plot(acc,val_acc,loss,val_loss):
    
    fig, (ax1, ax2) = plt.subplots(1,2, figsize= (15,10))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    plt.show()
    

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'])

# %%
y_pred=model.predict(x_test)
y_pred_prb=y_pred
print(Y_test)
print(y_pred)
# Out:
# [[0. 0. 1.]
#  [1. 0. 0.]
#  [0. 1. 0.]
#  ...
#  [1. 0. 0.]
#  [1. 0. 0.]
#  [0. 1. 0.]]
# [[4.9726128e-07 8.6616574e-06 9.9999082e-01]
#  [9.9999511e-01 1.2106761e-06 3.6892441e-06]
#  [3.7946215e-08 9.9999928e-01 7.7336904e-07]
#  ...
#  [9.9999297e-01 6.1034257e-07 6.4355158e-06]
#  [9.6095484e-01 1.2386387e-02 2.6658881e-02]
#  [1.6901964e-04 9.9983096e-01 1.2365726e-12]]

# %%
pred = []
for x in y_pred:
    if x[0] > x[1] and x[0] > x[2]:
        pred.append(0)
    elif x[1] > x[0] and x[1] > x[2]:
        pred.append(1)
    elif x[2] > x[0] and x[2] > x[1]:
        pred.append(2)
pred = np.array(pred)
print(pred)
print(y_test)
# Out:
# [2 0 1 ... 0 0 1]
# [2 0 1 ... 0 0 1]

# %%
pred_prb = []
for x in y_pred_prb:
    if x[0] > x[1] and x[0] > x[2]:
        pred_prb.append(x[0])
    elif x[1] > x[0] and x[1] > x[2]:
        pred_prb.append(x[1])
    elif x[2] > x[0] and x[2] > x[1]:
        pred_prb.append(x[2])
pred_prb = np.array(pred_prb)
print(pred_prb)
# Out:
# [0.9999908  0.9999951  0.9999993  ... 0.99999297 0.96095484 0.99983096]

# %%
from sklearn import metrics
target=["Normal","Abnomral- Benign","Abnormal- Malignant"]
print('Accuracy:', np.round(metrics.accuracy_score(y_test, pred),4))
print('Precision:', np.round(metrics.precision_score(y_test, pred, average='weighted'),4))
print('Recall:', np.round(metrics.recall_score(y_test,pred, average='weighted'),4))
print('F1 Score:', np.round(metrics.f1_score(y_test, pred, average='weighted'),4))
print('ROC AUC Score:', np.round(metrics.roc_auc_score(y_test, y_pred_prb,multi_class='ovr', average='weighted'),4))
print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(y_test, pred),4))
print('\t\tClassification Report:\n', metrics.classification_report(y_test, pred,target_names=target))
# Out:
# Accuracy: 0.9884
# Precision: 0.9885
# Recall: 0.9884
# F1 Score: 0.9884
# ROC AUC Score: 0.9994
# Cohen Kappa Score: 0.9778
# 		Classification Report:
#                       precision    recall  f1-score   support
#
#              Normal       0.99      0.99      0.99     14933
#    Abnomral- Benign       0.98      0.98      0.98      4616
# Abnormal- Malignant       0.99      0.97      0.98      3635
#
#            accuracy                           0.99     23184
#           macro avg       0.99      0.98      0.98     23184
#        weighted avg       0.99      0.99      0.99     23184

# %%
model.save("MIAS_model.h5")
print("model saved to disk")
# Out:
# model saved to disk

# %%
from keras.models import load_model
loaded_new_model = load_model("MIAS_model.h5")
loaded_new_model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 64, 64, 64)        640
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 64, 64, 64)        36928
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# dense_19 (Dense)             (None, 16, 16, 64)        8256
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 16384)             0
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 49155
# =================================================================
# Total params: 316,419
# Trainable params: 316,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_value , accuracy = loaded_new_model.evaluate(x_test, Y_test)
print('Test_loss_value = ' + str(loss_value))
print('test_accuracy = ' + str(accuracy))
# Out:
# 23184/23184 [==============================] - 81s 4ms/step
# Test_loss_value = 0.4846756114419408
# test_accuracy = 0.900017261505127

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=1, random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
(a,b,c)=x_train.shape
x_train = np.reshape(x_train, (a, b, c, 1))  #1 for gray scale
(a, b, c)=x_test.shape
x_test = np.reshape(x_test, (a, b, c, 1))   #1 for gray scale
print(x_train.shape)
print(x_test.shape)

Y_test = to_categorical(y_test)
Y_train = to_categorical(y_train)

loss_value , accuracy = loaded_new_model.evaluate(x_test, Y_test)

print('Test_loss_value = ' + str(loss_value))
print('test_accuracy = ' + str(accuracy))


y_pred=loaded_new_model.predict(x_test)
y_pred_prb=y_pred

pred = []
for x in y_pred:
    if x[0] > x[1] and x[0] > x[2]:
        pred.append(0)
    elif x[1] > x[0] and x[1] > x[2]:
        pred.append(1)
    elif x[2] > x[0] and x[2] > x[1]:
        pred.append(2)
pred = np.array(pred)

pred_prb = []
for x in y_pred_prb:
    if x[0] > x[1] and x[0] > x[2]:
        pred_prb.append(x[0])
    elif x[1] > x[0] and x[1] > x[2]:
        pred_prb.append(x[1])
    elif x[2] > x[0] and x[2] > x[1]:
        pred_prb.append(x[2])
pred_prb = np.array(pred_prb)

from sklearn import metrics
target=["Normal","Abnomral- Benign","Abnormal- Malignant"]
print('Accuracy:', np.round(metrics.accuracy_score(y_test, pred),4))
print('Precision:', np.round(metrics.precision_score(y_test, pred, average='weighted'),4))
print('Recall:', np.round(metrics.recall_score(y_test,pred, average='weighted'),4))
print('F1 Score:', np.round(metrics.f1_score(y_test, pred, average='weighted'),4))
print('ROC AUC Score:', np.round(metrics.roc_auc_score(y_test, y_pred_prb,multi_class='ovr', average='weighted'),4))
print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(y_test, pred),4))
print('\t\tClassification Report:\n', metrics.classification_report(y_test, pred,target_names=target))
# Out:
# (115919, 64, 64)
# (1, 64, 64)
# (115919,)
# (1,)
# (115919, 64, 64, 1)
# (1, 64, 64, 1)
# 1/1 [==============================] - 1s 1s/step
# Test_loss_value = 3.576278118089249e-07
# test_accuracy = 1.0
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-e341166b4aa5> in <module>
#      49 print('Recall:', np.round(metrics.recall_score(y_test,pred, average='weighted'),4))
#      50 print('F1 Score:', np.round(metrics.f1_score(y_test, pred, average='weighted'),4))
# ---> 51 print('ROC AUC Score:', np.round(metrics.roc_auc_score(y_test, y_pred_prb,multi_class='ovr', average='weighted'),4))
#      52 print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(y_test, pred),4))
#      53 print('\t\tClassification Report:\n', metrics.classification_report(y_test, pred,target_names=target))
#
# ~\.conda\envs\tensorflow_gpu\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\.conda\envs\tensorflow_gpu\lib\site-packages\sklearn\metrics\_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     536             raise ValueError("multi_class must be in ('ovo', 'ovr')")
#     537         return _multiclass_roc_auc_score(y_true, y_score, labels,
# --> 538                                          multi_class, average, sample_weight)
#     539     elif y_type == "binary":
#     540         labels = np.unique(y_true)
#
# ~\.conda\envs\tensorflow_gpu\lib\site-packages\sklearn\metrics\_ranking.py in _multiclass_roc_auc_score(y_true, y_score, labels, multi_class, average, sample_weight)
#     630         if len(classes) != y_score.shape[1]:
#     631             raise ValueError(
# --> 632                 "Number of classes in y_true not equal to the number of "
#     633                 "columns in 'y_score'")
#     634
#
# ValueError: Number of classes in y_true not equal to the number of columns in 'y_score'
